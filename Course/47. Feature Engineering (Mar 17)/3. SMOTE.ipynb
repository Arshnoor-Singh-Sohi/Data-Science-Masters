# %% [markdown]
# ## SMOTE (Synthetic Minority Oversampling Technique)

# %%
from sklearn.datasets import make_classification

# %%
## X independent Feature
## y dependent feature
X, y = make_classification(n_samples = 1000, 
                    n_features = 2,
                    n_redundant=0,
                    n_clusters_per_class=1,
                    weights=[0.90],
                    random_state=1
                   )

# %%
import pandas as pd
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1, df2], axis = 1)

# %%
final_df
# Out:
#            f1        f2  target
# 0    1.536830 -1.398694       1
# 1    1.551108  1.810329       0
# 2    1.293619  1.010946       0
# 3    1.119889  1.632518       0
# 4    1.042356  1.121529       0
# ..        ...       ...     ...
# 995  2.210439  2.006772       0
# 996  1.910941  2.011860       0
# 997 -0.556625 -0.159837       0
# 998  1.004999  0.936290       0
# 999  1.462110  1.144978       0
#
# [1000 rows x 3 columns]

# %%
final_df['target'].value_counts()
# Out:
# 0    894
# 1    106
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Requirement already satisfied: imbalanced-learn in c:\users\arshn\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\arshn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\arshn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\arshn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\arshn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arshn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %%
from imblearn.over_sampling import SMOTE

# %%
## Transform the dataset
oversample = SMOTE()
X,y = oversample.fit_resample(final_df[['f1','f2']], final_df['target'])

# %%
X.shape
# Out:
# (1788, 2)

# %%
y.shape
# Out:
# (1788,)

# %%
len(y[y == 0])
# Out:
# 894

# %%
len(y[y == 1])
# Out:
# 894

# %%
import pandas as pd
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
oversampled_df = pd.concat([df1, df2], axis = 1)

# %%
plt.scatter(oversampled_df['f1'], oversampled_df['f2'], c=oversampled_df['target'])
